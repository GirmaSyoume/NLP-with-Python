# %%
import pandas as pd
import geopandas as gpd
import os
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.remote.webdriver import WebDriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
chrome_options = webdriver.ChromeOptions()
preferences = {
                "profile.default_content_settings.popups": 0,
                "download.default_directory": os.getcwd() + os.path.sep,
                "directory_upgrade": True}

chrome_options.add_experimental_option('prefs', preferences)
driver = webdriver.Chrome(executable_path= r"C:\Users\gsyoume\Downloads\chromedriver_win32\chromedriver.exe", options=chrome_options)

# %%
driver.get('https://www.wbez.org/stories/map-by-zip-code-of-coronavirus-covid-19-cases-illinois/90ca85cd-bdf4-423a-a7bc-924fcee9d0f3')

time.sleep(20)

# %%
driver.find_element_by_xpath('//*[@id="wilmington-ButtonElement--zSFesjrbcldOhzFIi11c"]').click()

# %%
lists = []
element = driver.find_element_by_xpath("//*[@id='observablehq-6d4af12f']/div/div/div[2]/div[1]/div[1]/span[2]/span/select")
all_options = element.find_elements_by_tag_name("option")
for option in all_options:
    #print("Value is: %s" % option.get_attribute("value"))
    option.click()
    time.sleep(3)
    x = driver.find_element_by_xpath("//*[contains(.,'is in the City of Chicago')]")
    y=x.text
    lists.append(y)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-19-fe40ce21b45e> in <module>
#       6     option.click()
#       7     time.sleep(3)
# ----> 8     x = driver.find_element_by_xpath("//*[contains(.,'is in the City of Chicago')]")
#       9     y=x.text
#      10     lists.append(y)
#
# ~\Documents\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Documents\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
lists
# Out:
# ["SKIP TO MAIN CONTENT\nWBEZ.org\nLISTEN LIVE\nSEARCH\nMENU\nDONATE\nEnvironment & Public Health Coronavirus In Illinois\nMAP: Find The Number Of COVID-19 Cases In Illinois By ZIP Code\nBy David Eads, Chicago Reporter, Paula Friedrich\nApril 14, 6 a.m. CT\nHaz clic aquí para la versión en español.\nFind the latest COVID-19 case counts and case demographics for your area, as reported by the Illinois Department of Public Health (IDPH), with the lookup tool below, presented here in collaboration with The Chicago Reporter.\nSee more: Charts tracking the rise of Illinois COVID-19 cases\nTotal cases\n6-283\n283-993\n993-2,370\n2,370-4,367\n© Mapbox © OpenStreetMap Improve this map\nAs of August 18, ZIP code\n        60002 : 173 cases, Lake\n60004 : 495 cases, Cook\n60005 : 331 cases, Cook\n60007 : 457 cases, Cook\n60008 : 466 cases, Cook\n60010 : 363 cases, Lake\n60012 : 130 cases, McHenry\n60013 : 234 cases, McHenry\n60014 : 538 cases, McHenry\n60015 : 292 cases, Lake\n60016 : 1340 cases,
# ...

# %%
lists[0]
# Out:
# "SKIP TO MAIN CONTENT\nWBEZ.org\nLISTEN LIVE\nSEARCH\nMENU\nDONATE\nEnvironment & Public Health Coronavirus In Illinois\nMAP: Find The Number Of COVID-19 Cases In Illinois By ZIP Code\nBy David Eads, Chicago Reporter, Paula Friedrich\nApril 14, 6 a.m. CT\nHaz clic aquí para la versión en español.\nFind the latest COVID-19 case counts and case demographics for your area, as reported by the Illinois Department of Public Health (IDPH), with the lookup tool below, presented here in collaboration with The Chicago Reporter.\nSee more: Charts tracking the rise of Illinois COVID-19 cases\nTotal cases\n6-283\n283-993\n993-2,370\n2,370-4,367\n© Mapbox © OpenStreetMap Improve this map\nAs of August 18, ZIP code\n        60002 : 173 cases, Lake\n60004 : 495 cases, Cook\n60005 : 331 cases, Cook\n60007 : 457 cases, Cook\n60008 : 466 cases, Cook\n60010 : 363 cases, Lake\n60012 : 130 cases, McHenry\n60013 : 234 cases, McHenry\n60014 : 538 cases, McHenry\n60015 : 292 cases, Lake\n60016 : 1340 cases, 
# ...

# %%
lists[0]
# Out:
# "SKIP TO MAIN CONTENT\nWBEZ.org\nLISTEN LIVE\nSEARCH\nMENU\nDONATE\nEnvironment & Public Health Coronavirus In Illinois\nMAP: Find The Number Of COVID-19 Cases In Illinois By ZIP Code\nBy David Eads, Chicago Reporter, Paula Friedrich\nApril 14, 6 a.m. CT\nHaz clic aquí para la versión en español.\nFind the latest COVID-19 case counts and case demographics for your area, as reported by the Illinois Department of Public Health (IDPH), with the lookup tool below, presented here in collaboration with The Chicago Reporter.\nSee more: Charts tracking the rise of Illinois COVID-19 cases\nTotal cases\n6-283\n283-993\n993-2,370\n2,370-4,367\n© Mapbox © OpenStreetMap Improve this map\nAs of August 18, ZIP code\n        60002 : 173 cases, Lake\n60004 : 495 cases, Cook\n60005 : 331 cases, Cook\n60007 : 457 cases, Cook\n60008 : 466 cases, Cook\n60010 : 363 cases, Lake\n60012 : 130 cases, McHenry\n60013 : 234 cases, McHenry\n60014 : 538 cases, McHenry\n60015 : 292 cases, Lake\n60016 : 1340 cases, 
# ...
